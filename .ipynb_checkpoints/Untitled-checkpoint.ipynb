# %%
import pandas as pd
df = pd.read_csv('GreenThumb_Garden_Info.csv')
df
# Out:
#      assemblydist borough  communityboard  congressionaldist  coundist  \
# 0              53       B             301                  7        34
# 1              53       B             301                  7        34
# 2              68       M             111                 13         8
# 3              57       B             302                 10        35
# 4              55       B             316                  8        41
# ..            ...     ...             ...                ...       ...
# 608            29       Q             412                  5        27
# 609            56       B             308                  9        36
# 610            56       B             303                  8        36
# 611            69       M             107                 12         6
# 612            53       B             301                  7        34
#
#                                    gardenname juris  \
# 0                   Sunshine Community Garden   DPR
# ...

# %%
input("What's your zipcode?")

# %%
if user_zipcode == df['zipcode']:
    print("There's a garden in this zipcode.")
else:
    print("There's no garden in this zipcode.")
